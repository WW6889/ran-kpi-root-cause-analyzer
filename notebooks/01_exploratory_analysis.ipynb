# %% [markdown]
# # RAN KPI Exploratory Analysis
#
# This notebook is intentionally lightweight. The production workflow is implemented in the package and CLI.

# %%
import pandas as pd
data = pd.read_csv('../data/raw/sample_ran_kpi_data.csv')
data.head()

# %%
data.groupby('cell_id')[['rsrp_dbm', 'sinr_db', 'prb_utilization_dl', 'throughput_dl_mbps']].mean().round(2)
